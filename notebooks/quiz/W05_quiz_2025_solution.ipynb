# %% [markdown]
# # Week 5 Quiz
#
# This notebook contains the SQL Quiz for Week 5. Section 1 uses the New York City data we know and love. Section 2 uses building footprint data from the Google Open Buildings dataset.
#
# INSTRUCTIONS:
#
# Run this notebook in Google Colab. The answer to each quesiton will be a number or a string. Input these into the corresponding question on Moodle. You have 90 minutes to attempt the quiz, so if you get stuck on a question, move on.
#
# Make sure you run all of the cells of code in order, especially the ones that already have code in them! If you run into serious problems, try clicking on the "runtime" tab above and selecting "restart session and run all".

# %%
# %pip install duckdb duckdb-engine jupysql leafmap
# Out:
# Requirement already satisfied: duckdb in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (0.9.2)
# Requirement already satisfied: duckdb-engine in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: jupysql in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (0.10.7)
# Requirement already satisfied: leafmap in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (0.31.5)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from duckdb-engine) (2.0.21)
# Requirement already satisfied: prettytable in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jupysql) (3.5.0)
# Requirement already satisfied: sqlparse in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jupysql) (0.4.4)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jupysql) (3.0.3)
# Requirement already satisfied: sqlglot>=11.3.7 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jupysql) (20.5.0)
# Requirement already satisfied: ploomber-core>=0.2.7 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jupysql) (0.2.19)
# Requirement already satisfied: jupysql-plugin in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jupysql) (0.3.1)
# Requirement already satisfied: bqplot in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (0.12.43)
# Requirement already satisfied: colour in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (0.1.5)
# Requirement already satisfied: folium in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (0.19.2)
# Requirement already satisfied: gdown in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (4.4.0)
# Requirement already satisfied: geojson in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (2.5.0)
# Requirement already satisfied: ipyevents in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (2.0.1)
# Requirement already satisfied: ipyfilechooser in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (0.6.0)
# Requirement already satisfied: ipyleaflet in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (0.19.2)
# Requirement already satisfied: ipywidgets in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (7.6.5)
# Requirement already satisfied: matplotlib in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (3.8.0)
# Requirement already satisfied: numpy in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (1.26.4)
# Requirement already satisfied: pandas in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (2.0.3)
# Requirement already satisfied: plotly in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (5.6.0)
# Requirement already satisfied: pyshp in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (2.3.1)
# Requirement already satisfied: pystac-client in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (0.6.1)
# Requirement already satisfied: python-box in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (5.4.1)
# Requirement already satisfied: scooby in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (0.7.2)
# Requirement already satisfied: whiteboxgui in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (0.7.0)
# Requirement already satisfied: xyzservices in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from leafmap) (2024.9.0)
# Requirement already satisfied: click in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ploomber-core>=0.2.7->jupysql) (8.1.3)
# Requirement already satisfied: pyyaml in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.1)
# Requirement already satisfied: posthog in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ploomber-core>=0.2.7->jupysql) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from sqlalchemy>=1.3.22->duckdb-engine) (4.7.1)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from bqplot->leafmap) (5.14.1)
# Requirement already satisfied: traittypes>=0.0.6 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from bqplot->leafmap) (0.2.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipywidgets->leafmap) (6.25.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipywidgets->leafmap) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipywidgets->leafmap) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipywidgets->leafmap) (8.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipywidgets->leafmap) (1.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from pandas->leafmap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from pandas->leafmap) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from pandas->leafmap) (2023.3)
# Requirement already satisfied: branca>=0.6.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from folium->leafmap) (0.8.1)
# Requirement already satisfied: requests in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from folium->leafmap) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jinja2->jupysql) (2.1.2)
# Requirement already satisfied: filelock in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from gdown->leafmap) (3.6.0)
# Requirement already satisfied: six in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from gdown->leafmap) (1.16.0)
# Requirement already satisfied: tqdm in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from gdown->leafmap) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from gdown->leafmap) (4.10.0)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipyleaflet->leafmap) (0.19.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from matplotlib->leafmap) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from matplotlib->leafmap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from matplotlib->leafmap) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from matplotlib->leafmap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from matplotlib->leafmap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from matplotlib->leafmap) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from matplotlib->leafmap) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from matplotlib->leafmap) (5.12.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from plotly->leafmap) (8.2.2)
# Requirement already satisfied: wcwidth in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from prettytable->jupysql) (0.2.5)
# Requirement already satisfied: pystac>=1.7.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from pystac-client->leafmap) (1.7.3)
# Requirement already satisfied: ipytree in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from whiteboxgui->leafmap) (0.2.1)
# Requirement already satisfied: whitebox in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from whiteboxgui->leafmap) (2.1.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->leafmap) (3.11.0)
# Requirement already satisfied: appnope in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (7.1.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (0.1.3)
# Requirement already satisfied: nest-asyncio in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (1.5.4)
# Requirement already satisfied: psutil in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (22.3.0)
# Requirement already satisfied: tornado>=6.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (6.3.3)
# Requirement already satisfied: backcall in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->leafmap) (0.2.0)
# Requirement already satisfied: decorator in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->leafmap) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->leafmap) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->leafmap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->leafmap) (3.0.28)
# Requirement already satisfied: pygments>=2.4.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->leafmap) (2.15.1)
# Requirement already satisfied: setuptools>=18.5 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->leafmap) (68.0.0)
# Requirement already satisfied: stack-data in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->leafmap) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->leafmap) (4.8.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->leafmap) (4.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from requests->folium->leafmap) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from requests->folium->leafmap) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from requests->folium->leafmap) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from requests->folium->leafmap) (2024.8.30)
# Requirement already satisfied: notebook>=4.4.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->leafmap) (6.4.8)
# Requirement already satisfied: soupsieve>1.2 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from beautifulsoup4->gdown->leafmap) (2.3.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from requests[socks]->gdown->leafmap) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->leafmap) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->leafmap) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->leafmap) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->leafmap) (0.10.6)
# Requirement already satisfied: entrypoints in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->leafmap) (3.10.0)
# Requirement already satisfied: argon2-cffi in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (21.3.0)
# Requirement already satisfied: nbconvert in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (6.4.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (0.13.2)
# Requirement already satisfied: prometheus-client in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (0.13.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap) (0.7.0)
# Requirement already satisfied: executing in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->leafmap) (0.8.3)
# Requirement already satisfied: asttokens in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->leafmap) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->leafmap) (0.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (21.2.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (0.1.2)
# Requirement already satisfied: bleach in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (1.5.0)
# Requirement already satisfied: testpath in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (0.6.0)
# Requirement already satisfied: defusedxml in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (0.5.11)
# Requirement already satisfied: cffi>=1.0.1 in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (1.17.1)
# Requirement already satisfied: webencodings in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (0.5.1)
# Requirement already satisfied: pycparser in /Users/ollieballinger/miniconda3/envs/geo/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->leafmap) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb
import leafmap
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %%sql
# duckdb:///:memory:
# INSTALL spatial;
# LOAD spatial;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# # Section 1

# %% [markdown]
# The code below downloads the data on New York City that we've been working with so far.

# %%
url='https://s3.amazonaws.com/s3.cleverelephant.ca/postgis-workshop-2020.zip'
leafmap.download_file(url, unzip=True)
# Out:
# Downloading...
# From: https://s3.amazonaws.com/s3.cleverelephant.ca/postgis-workshop-2020.zip
# To: /Users/ollieballinger/Google Drive/Work/UCL/Teaching/CASA0025 BSABD/CASA0025/notebooks/quiz/postgis-workshop-2020.zip
# 100%|██████████| 22.5M/22.5M [00:30<00:00, 748kB/s]
# Extracting files...
# '/Users/ollieballinger/Google Drive/Work/UCL/Teaching/CASA0025 BSABD/CASA0025/notebooks/quiz/postgis-workshop-2020.zip'

# %% [markdown]
# The following line of code creates a table called `nyc_neighborhoods` from a shapefile called `nyc_neighborhoods.shp`, located in the `postgis-workshop/data/` folder.

# %%
# %%sql
#
# CREATE TABLE nyc_neighborhoods AS SELECT * FROM "postgis-workshop/data/nyc_neighborhoods.shp";
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# The `%%sql` at the top of the cell allows you to run SQL code in the rest of the cell:

# %%
# %%sql
#
# SELECT * FROM nyc_neighborhoods;
# Out:
#           BORONAME                      NAME  \
# 0         Brooklyn               Bensonhurst
# 1        Manhattan              East Village
# 2        Manhattan              West Village
# 3        The Bronx              Throggs Neck
# 4        The Bronx  Wakefield-Williamsbridge
# ..             ...                       ...
# 124       Brooklyn                  Red Hook
# 125         Queens   Douglastown-Little Neck
# 126         Queens                Whitestone
# 127         Queens                  Steinway
# 128  Staten Island                  Rosebank
#
#                                                   geom
# 0    [2, 4, 33, 0, 0, 0, 0, 0, 54, 71, 14, 73, 198,...
# 1    [2, 4, 144, 0, 0, 0, 0, 0, 35, 215, 14, 73, 13...
# 2    [2, 4, 83, 0, 0, 0, 0, 0, 161, 95, 14, 73, 212...
# 3    [2, 4, 133, 0, 0, 0, 0, 0, 128, 232, 17, 73, 1...
# 4    [2, 4, 118, 0, 0, 0, 0, 0, 83, 85, 17, 73, 17,...
# ..                                                 ...
# 124  [5, 4, 56, 0, 0, 0, 0, 0, 18, 0, 14, 73, 149, ...
# 125  [2, 4, 236, 0, 0, 0, 0, 0, 251, 165, 19, 73, 7...
# 126  [5, 4, 236, 0, 0, 0, 0, 0, 17, 75, 18, 73, 86,...
# 127  [5, 4, 63, 0, 0, 0, 0, 0, 124, 87, 16, 73, 87,...
# 128  [2, 4, 66, 0, 0, 0, 0, 0, 176, 94, 13, 73, 11,...
#
# [129 rows x 3 columns]

# %% [markdown]
# ## Question 1
#
# Create the following tables using the corresponding shapefiles.
# - nyc_census_blocks
# - nyc_homicides
# - nyc_streets
# - nyc_subway_stations

# %%
# %%sql
# CREATE TABLE nyc_streets AS SELECT * FROM "postgis-workshop/data/nyc_streets.shp";
# CREATE TABLE nyc_subway_stations AS SELECT * FROM "postgis-workshop/data/nyc_subway_stations.shp";
# CREATE TABLE nyc_census_blocks AS SELECT * FROM "postgis-workshop/data/nyc_census_blocks.shp";
# CREATE TABLE nyc_homicides AS SELECT * FROM "postgis-workshop/data/nyc_homicides.shp";
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Question 2:
# How many rows are there in the nyc_homicides table?

# %%
# %%sql
# SELECT count(*) FROM nyc_homicides;
# Out:
#    count_star()
# 0          3983

# %% [markdown]
# ## Question 3:
#
# How many homicides were there in Brooklyn in 2008?

# %%
# %%sql
# SELECT count(*)
# FROM nyc_homicides
# WHERE BORONAME = 'Brooklyn'
# AND YEAR = 2008
# Out:
#    count_star()
# 0           206

# %% [markdown]
# ## Question 4:
#
# Which neighborhood of New York had the most murders in 2010?

# %%
# %%sql
# SELECT n.NAME as neighborhood, count(*) as murders
# FROM nyc_homicides as h
# JOIN nyc_neighborhoods as n
# ON ST_WITHIN(h.geom, n.geom)
# WHERE h.YEAR = 2010
# GROUP BY neighborhood
# ORDER BY murders DESC
# Out:
#              neighborhood  murders
# 0      Bedford-Stuyvesant       30
# 1             South Bronx       21
# 2                  Harlem       14
# 3           East Brooklyn       13
# 4                 Jamaica       10
# ..                    ...      ...
# 62  Westerleigh-Castleton        1
# 63            Bensonhurst        1
# 64          Midland Beach        1
# 65          Ardon Heights        1
# 66              Annandale        1
#
# [67 rows x 2 columns]

# %% [markdown]
# ## Question 5
#
# Calculate the per-capita murder rates for each borough of New York.

# %%
# %%sql
# SELECT c.BORONAME as borough, count(h.*)/SUM(c.POPN_TOTAL) as murders_pc
# FROM nyc_homicides as h
# JOIN nyc_census_blocks as c
# ON ST_WITHIN(h.geom, c.geom)
# GROUP BY borough
# ORDER BY murders_pc DESC
# Out:
#          borough  murders_pc
# 0  Staten Island    0.003534
# 1         Queens    0.003199
# 2       Brooklyn    0.001781
# 3      The Bronx    0.001562
# 4      Manhattan    0.001339

# %% [markdown]
# # Section 2
#
# This section uses building footprint data generated by Google. Each row is a polygon that specifies the outline of a building detected using AI and satellite imagery.
#
# ![](https://sites.research.google/open-buildings/static/img/buildings-header-light-cropped.png)
#
# We're going to be working with all of the building footprints identified in Kigali, the capital city of Rwanda.
#
# The code below creates a table called `kigali_buildings` by reading a parquet file hosted a the URL in the final line.

# %%
# %%sql
#
# CREATE TABLE kigali_buildings AS
# SELECT full_plus_code as building_id, ST_GeomFromWKB(geometry) as geom
# FROM read_parquet('https://data.source.coop/cholmes/google-open-buildings/v2/geoparquet-admin1/country=RWA/City_of_Kigali.parquet');
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# Our table has two columns; one called `building_id` which is a unique identifier for each building footprint, and `geom` which contains the geometry information.

# %%
# %%sql
# select * from kigali_buildings
# Out:
#                admin_1    building_id  confidence  \
# 0       City of Kigali  6G9FWXPV+VQRP      0.6472
# 1       City of Kigali  6G9FWXPV+WP9F      0.6473
# 2       City of Kigali  6G9FWXPV+WPV9      0.6338
# 3       City of Kigali  6G9FWXPV+WQ3R      0.7050
# 4       City of Kigali  6G9FWXPV+WQWC      0.7966
# ...                ...            ...         ...
# 786870  City of Kigali  6GCG6553+2XP4      0.6250
# 786871  City of Kigali  6GCG6553+2XQ9      0.6284
# 786872  City of Kigali  6GCG6556+26H3      0.7305
# 786873  City of Kigali  6GCG6556+27F9      0.8145
# 786874  City of Kigali  6GCG6556+27R9      0.6172
#
#                                                      geom
# 0       [2, 4, 96, 0, 0, 0, 0, 0, 127, 244, 239, 65, 1...
# 1       [2, 4, 96, 0, 0, 0, 0, 0, 100, 244, 239, 65, 2...
# 2       [2, 4, 96, 0, 0, 0, 0, 0, 77, 244, 239, 65, 14...
# 3       [2, 4, 96, 0, 0, 0, 0, 0, 129, 244, 239, 65, 1...
# 4       [2, 4, 96, 0, 0, 0, 0, 0, 132, 244, 239, 65, 0...
# ...                                                   ...
# 786870  [2, 4, 128, 0, 0, 0, 0, 0, 79, 61, 241, 65, 22...
# 786871  [2, 4, 96, 0, 0, 0, 0, 0, 98, 61, 241, 65, 212...
# 786872  [2, 4, 96, 0, 0, 0, 0, 0, 224, 72, 241, 65, 17...
# 786873  [2, 4, 128, 0, 0, 0, 0, 0, 250, 72, 241, 65, 6...
# 786874  [2, 4, 96, 0, 0, 0, 0, 0, 243, 72, 241, 65, 24...
#
# [786875 rows x 4 columns]

# %% [markdown]
# ## Question 6
# Complete the code below to create a column called `area` which calculates the area of each building using the `geom` column and multiply the result by 12356260000 to get the area in meters.

# %%
# %%sql
# ALTER TABLE kigali_buildings ADD COLUMN area DOUBLE;
# UPDATE kigali_buildings SET area =  ST_Area(geom)*12356260000
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## Question 7
#
# How many buildings in Kigali are larger than 100 square meters?

# %%
# %%sql
# SELECT COUNT(*)
# FROM kigali_buildings
# WHERE area>100;
# Out:
#    count_star()
# 0        101937

# %% [markdown]
# ## Question 8
#
# How many square meters is the largest building in Kigali?

# %%
# %%sql
# SELECT building_id, area
# FROM kigali_buildings
# ORDER BY area DESC
# Out:
#           building_id         area
# 0       6GCG43HP+PJH7  6703.286316
# 1       6GCG3572+QXJ4  6697.154950
# 2       6GCG24C5+4HHC  5982.208029
# 3       6GCG23HJ+6FQ7  5960.072035
# 4       6GCG257Q+MH85  5096.519344
# ...               ...          ...
# 786870  6GCG22RX+P6XW     2.267773
# 786871  6GCG22GV+6V8P     2.250158
# 786872  6GCG537H+488J     2.196751
# 786873  6GCG34Q7+XQ69     2.191241
# 786874  6GCG34WC+J654     2.007717
#
# [786875 rows x 2 columns]

# %% [markdown]
# ## Question 9
#
# How many buildings are within a distance of 0.001 from the largest building in Kigali? (be careful)

# %%
# %%sql
# SELECT COUNT(*)
# FROM kigali_buildings AS a
# JOIN kigali_buildings AS b
# ON ST_DWithin(a.geom, b.geom, 0.001)
# AND a.building_id != b.building_id
# AND a.area >6703
# Out:
#    count_star()
# 0             7

# %% [markdown]
# ## Question 10
#
# A common characteristic of informal settlements (sometimes referred to as "slums") is the presence of a large number of buildings in close proximity to each other. In this question, we are going to create a measure of building density.
#
# First, let's create a new table called `sample` which contains the first 1000 rows of data in our datset:

# %%
# %%sql
#
# CREATE TABLE sample AS SELECT * FROM kigali_buildings limit 1000;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# Spatially join the `sample` table to itself to identify buildings within a distance of 0.001 of each other. (Hint: `count` and `group by` will be useful functions).
#
# What is the `building_id` of the building with the greatest number of buildings within a distance of 0.001?

# %%
# %%sql
#
# SELECT a.building_id, COUNT(*) as count
# FROM sample AS a
# JOIN sample AS b
# ON ST_DWithin(a.geom, b.geom, 0.001)
# AND a.building_id <> b.building_id
# GROUP BY a.building_id
# ORDER BY count DESC
# Out:
#        building_id  count
# 0    6G9FXX2V+Q8HP     95
# 1    6G9FWXVQ+CWQ5     94
# 2    6G9FXX2V+M8CJ     94
# 3    6G9FXX2V+M8MR     94
# 4    6G9FXX2V+Q92V     94
# ..             ...    ...
# 995  6G9FWXWW+7CRW      3
# 996  6G9FWXWW+8996      3
# 997  6G9FWXXV+6QMW      2
# 998  6G9FWXXV+5M4X      2
# 999  6G9FWXRQ+MVQR      1
#
# [1000 rows x 2 columns]
